# %%
import numpy as np

# %%
import pandas as pd

# %%
from scipy import stats

# %%
#1
a=np.array([1,2,3])
print(a[0])
print(a[2])
# Out:
# 1
# 3

# %%
#2
b=np.array([[1,2,3],[4,5,6]])
np.ndim(b)
print(b[1][2])
print(b[0])
# Out:
# 6
# [1 2 3]

# %%
#3
c=np.arange(1,10)
c[2:7]
# Out:
# array([3, 4, 5, 6, 7])

# %%
#4.replace
d=np.array([1,-1,2,-2,3,-3])
d[d<0]=0
d
# Out:
# array([1, 0, 2, 0, 3, 0])

# %%
#5.
print(a)
print(b)
a+b
# Out:
# [1 2 3]
# [[1 2 3]
#  [4 5 6]]
# array([[2, 4, 6],
#        [5, 7, 9]])

# %%
#6.unique and value_counts
vi=np.array([1,2,2,3,3,3,4])
vj=np.unique(vi,return_counts=True)
vj
# Out:
# (array([1, 2, 3, 4]), array([1, 2, 3, 1]))

# %%
#9
d={"name":["vj","luffy","zoro","sanji","nami","ussop"],"marks":[90,35,40,70,99,55]}
df=pd.DataFrame(d)
df
# Out:
#     name  marks
# 0     vj     90
# 1  luffy     35
# 2   zoro     40
# 3  sanji     70
# 4   nami     99
# 5  ussop     55

# %%
#6

six=df["marks"].unique()
print(six)
six1=df["marks"].value_counts()
print(six1)
# Out:
# [90 35 40 70 99 55]
# marks
# 90    1
# 35    1
# 40    1
# 70    1
# 99    1
# 55    1
# Name: count, dtype: int64

# %%
#7.replace even with zero
a1=np.array([1,2,3,4,5,6,7,8])
a1[a1%2==0]=0
a1
# Out:
# array([1, 0, 3, 0, 5, 0, 7, 0])

# %%
#8.multiply using array loop and vectorization
a2=np.array([1,2,3,4])
#loop
result=np.array([x*2 for x in a2])
print(result)
#vectorization
result1=a2*2
print(result1)
# Out:
# [2 4 6 8]
# [2 4 6 8]

# %%
#10 add column
df['grade']=df['marks'].apply(lambda x:'A' if x>=70 else('B' if x>=50 else 'c'))
df
# Out:
#     name  marks grade
# 0     vj     90     A
# 1  luffy     35     c
# 2   zoro     40     c
# 3  sanji     70     A
# 4   nami     99     A
# 5  ussop     55     B

# %%
#11,12
a12=df[df['marks']>=50]
a13=df['marks'].max()
a11=df['marks'].mean()
print(a12)
print(a11)
print(a13)
# Out:
#     name  marks grade
# 0     vj     90     A
# 3  sanji     70     A
# 4   nami     99     A
# 5  ussop     55     B
# 64.83333333333333
# 99

# %%
pip install matp
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
d=sns.load_dataset('tips')

# %%
d
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#15
c=["op","bleach","black"]
s=[1155,387,180]
plt.bar(c,s,color=["yellow","orange","red"])
plt.title("animie")
plt.xlabel("Best animies")
plt.ylabel("no of episodes")
plt.show()

# %%
#14
plt.plot(c,s)
plt.title("animie")
plt.xlabel("Best animies")
plt.ylabel("no of episodes")
plt.show()

# %%
#16
plt.pie([30,40,30],labels=['a','b','c'],autopct='%1.1f%%')
plt.show()

# %%
#17
e=d['total_bill'].mean()
f=d['total_bill'].median()
g=d['total_bill'].mode()[0]

# %%
#18
dt=[10,20,20,30,40]
print("range",np.ptp(dt))
print("variance",np.var(dt))
print("std deviation",np.std(dt))
# Out:
# range 30
# variance 104.0
# std deviation 10.198039027185569

# %%
#21
df[df['marks']<50]
# Out:
#     name  marks grade
# 1  luffy     35     c
# 2   zoro     40     c
