# %%
import pandas as pd

# %%
d=pd.read_csv("titanic.csv")

# %%
d
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
d.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
d.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
d.columns[d.isna().any()]
# Out:
# Index(['age', 'embarked', 'deck', 'embark_town'], dtype='object')

# %%
d['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
d['embarked']=d['embarked'].fillna(d['embarked'].mode()[0])
d.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
m=(d["sex"]=="female")&(d["survived"]==1)
m
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
e=pd.get_dummies(d["embarked"])
e
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 886  False  False   True
# 887  False  False   True
# 888  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [891 rows x 3 columns]

# %%
d.groupby("sex")["survived"].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
d.groupby("pclass")["survived"].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
d['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
d['age']=d['age'].fillna(d["age"].mean())
d['age']
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
d.columns[d.isna().any()]
# Out:
# Index(['deck', 'embark_town'], dtype='object')

# %%
d.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
s=pd.get_dummies(d['sex'])
d=pd.concat([d,s],axis=1)
d=d.drop("sex",axis="columns")
d
# Out:
#      survived  pclass        age  sibsp  parch     fare embarked   class  \
# 0           0       3  22.000000      1      0   7.2500        S   Third
# 1           1       1  38.000000      1      0  71.2833        C   First
# 2           1       3  26.000000      0      0   7.9250        S   Third
# 3           1       1  35.000000      1      0  53.1000        S   First
# 4           0       3  35.000000      0      0   8.0500        S   Third
# ..        ...     ...        ...    ...    ...      ...      ...     ...
# 886         0       2  27.000000      0      0  13.0000        S  Second
# 887         1       1  19.000000      0      0  30.0000        S   First
# 888         0       3  29.699118      1      2  23.4500        S   Third
# 889         1       1  26.000000      0      0  30.0000        C   First
# 890         0       3  32.000000      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone  female   male
# 0      man        True  NaN  Southampton    no  False   False   True
# 1    woman       False    C    Cherbourg   yes  False    True  False
# 2    woman       False  NaN  Southampton   yes   True    True  False
# 3    woman       False    C  Southampton   yes  False    True  False
# 4      man        True  NaN  Southampton    no   True   False   True
# ..     ...         ...  ...          ...   ...    ...     ...    ...
# 886    man        True  NaN  Southampton    no   True   False   True
# 887  woman       False    B  Southampton   yes   True    True  False
# 888  woman       False  NaN  Southampton    no  False    True  False
# 889    man        True    C    Cherbourg   yes   True   False   True
# 890    man        True  NaN   Queenstown    no   True   False   True
#
# [891 rows x 16 columns]

# %%
d.head(10)
# Out:
#    survived  pclass        age  sibsp  parch     fare embarked   class    who  \
# 0         0       3  22.000000      1      0   7.2500        S   Third    man
# 1         1       1  38.000000      1      0  71.2833        C   First  woman
# 2         1       3  26.000000      0      0   7.9250        S   Third  woman
# 3         1       1  35.000000      1      0  53.1000        S   First  woman
# 4         0       3  35.000000      0      0   8.0500        S   Third    man
# 5         0       3  29.699118      0      0   8.4583        Q   Third    man
# 6         0       1  54.000000      0      0  51.8625        S   First    man
# 7         0       3   2.000000      3      1  21.0750        S   Third  child
# 8         1       3  27.000000      0      2  11.1333        S   Third  woman
# 9         1       2  14.000000      1      0  30.0708        C  Second  child
#
#    adult_male deck  embark_town alive  alone  female   male
# 0        True  NaN  Southampton    no  False   False   True
# 1       False    C    Cherbourg   yes  False    True  False
# 2       False  NaN  Southampton   yes   True    True  False
# 3       False    C  Southampton   yes  False    True  False
# 4        True  NaN  Southampton    no   True   False   True
# 5        True  NaN   Queenstown    no   True   False   True
# 6        True    E  Southampton    no   True   False   True
# 7       False  NaN  Southampton    no  False   False   True
# 8       False  NaN  Southampton   yes  False    True  False
# 9       False  NaN    Cherbourg   yes  False    True  False

# %%
d.tail()
# Out:
#      survived  pclass        age  sibsp  parch   fare embarked   class    who  \
# 886         0       2  27.000000      0      0  13.00        S  Second    man
# 887         1       1  19.000000      0      0  30.00        S   First  woman
# 888         0       3  29.699118      1      2  23.45        S   Third  woman
# 889         1       1  26.000000      0      0  30.00        C   First    man
# 890         0       3  32.000000      0      0   7.75        Q   Third    man
#
#      adult_male deck  embark_town alive  alone  female   male
# 886        True  NaN  Southampton    no   True   False   True
# 887       False    B  Southampton   yes   True    True  False
# 888       False  NaN  Southampton    no  False    True  False
# 889        True    C    Cherbourg   yes   True   False   True
# 890        True  NaN   Queenstown    no   True   False   True

# %%
de={"name":["nisha","lisa","bosha","vijay","hussain","pradheepa","gavaskar","thaniyarasu","lokesh","anusha"],
"course":["DS","AI","AI","DS","DS","DS","AI","DA","DS","ML"]}
de
# Out:
# {'name': ['nisha',
#   'lisa',
#   'bosha',
#   'vijay',
#   'hussain',
#   'pradheepa',
#   'gavaskar',
#   'thaniyarasu',
#   'lokesh',
#   'anusha'],
#  'course': ['DS', 'AI', 'AI', 'DS', 'DS', 'DS', 'AI', 'DA', 'DS', 'ML']}

# %%
df=pd.DataFrame(de)
df
# Out:
#           name course
# 0        nisha     DS
# 1         lisa     AI
# 2        bosha     AI
# 3        vijay     DS
# 4      hussain     DS
# 5    pradheepa     DS
# 6     gavaskar     AI
# 7  thaniyarasu     DA
# 8       lokesh     DS
# 9       anusha     ML

# %%
d[(d['survived']>25)&(d["fare"]>50)]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, age, sibsp, parch, fare, embarked, class, who, adult_male, deck, embark_town, alive, alone, female, male]
# Index: []

# %%
d.sort_values("fare")
# Out:
#      survived  pclass        age  sibsp  parch      fare embarked   class  \
# 271         1       3  25.000000      0      0    0.0000        S   Third
# 597         0       3  49.000000      0      0    0.0000        S   Third
# 302         0       3  19.000000      0      0    0.0000        S   Third
# 633         0       1  29.699118      0      0    0.0000        S   First
# 277         0       2  29.699118      0      0    0.0000        S  Second
# ..        ...     ...        ...    ...    ...       ...      ...     ...
# 438         0       1  64.000000      1      4  263.0000        S   First
# 341         1       1  24.000000      3      2  263.0000        S   First
# 737         1       1  35.000000      0      0  512.3292        C   First
# 258         1       1  35.000000      0      0  512.3292        C   First
# 679         1       1  36.000000      0      1  512.3292        C   First
#
#        who  adult_male deck  embark_town alive  alone  female   male
# 271    man        True  NaN  Southampton   yes   True   False   True
# 597    man        True  NaN  Southampton    no   True   False   True
# 302    man        True  NaN  Southampton    no   True   False   True
# 633    man        True  NaN  Southampton    no   True   False   True
# 277    man        True  NaN  Southampton    no   True   False   True
# ..     ...         ...  ...          ...   ...    ...     ...    ...
# 438    man        True    C  Southampton    no  False   False   True
# 341  woman       False    C  Southampton   yes  False    True  False
# 737    man        True    B    Cherbourg   yes   True   False   True
# 258  woman       False  NaN    Cherbourg   yes   True    True  False
# 679    man        True    B    Cherbourg   yes  False   False   True
#
# [891 rows x 16 columns]

# %%
d.sort_values("fare",ascending=False)
# Out:
#      survived  pclass        age  sibsp  parch      fare embarked   class  \
# 258         1       1  35.000000      0      0  512.3292        C   First
# 737         1       1  35.000000      0      0  512.3292        C   First
# 679         1       1  36.000000      0      1  512.3292        C   First
# 88          1       1  23.000000      3      2  263.0000        S   First
# 27          0       1  19.000000      3      2  263.0000        S   First
# ..        ...     ...        ...    ...    ...       ...      ...     ...
# 633         0       1  29.699118      0      0    0.0000        S   First
# 413         0       2  29.699118      0      0    0.0000        S  Second
# 822         0       1  38.000000      0      0    0.0000        S   First
# 732         0       2  29.699118      0      0    0.0000        S  Second
# 674         0       2  29.699118      0      0    0.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone  female   male
# 258  woman       False  NaN    Cherbourg   yes   True    True  False
# 737    man        True    B    Cherbourg   yes   True   False   True
# 679    man        True    B    Cherbourg   yes  False   False   True
# 88   woman       False    C  Southampton   yes  False    True  False
# 27     man        True    C  Southampton    no  False   False   True
# ..     ...         ...  ...          ...   ...    ...     ...    ...
# 633    man        True  NaN  Southampton    no   True   False   True
# 413    man        True  NaN  Southampton    no   True   False   True
# 822    man        True  NaN  Southampton    no   True   False   True
# 732    man        True  NaN  Southampton    no   True   False   True
# 674    man        True  NaN  Southampton    no   True   False   True
#
# [891 rows x 16 columns]

# %%
d['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
d['survived'].value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
d[d['female']& d["survived"]]
# Out:
#      survived  pclass   age  sibsp  parch     fare embarked   class    who  \
# 1           1       1  38.0      1      0  71.2833        C   First  woman
# 2           1       3  26.0      0      0   7.9250        S   Third  woman
# 3           1       1  35.0      1      0  53.1000        S   First  woman
# 8           1       3  27.0      0      2  11.1333        S   Third  woman
# 9           1       2  14.0      1      0  30.0708        C  Second  child
# ..        ...     ...   ...    ...    ...      ...      ...     ...    ...
# 874         1       2  28.0      1      0  24.0000        C  Second  woman
# 875         1       3  15.0      0      0   7.2250        C   Third  child
# 879         1       1  56.0      0      1  83.1583        C   First  woman
# 880         1       2  25.0      0      1  26.0000        S  Second  woman
# 887         1       1  19.0      0      0  30.0000        S   First  woman
#
#      adult_male deck  embark_town alive  alone  female   male
# 1         False    C    Cherbourg   yes  False    True  False
# 2         False  NaN  Southampton   yes   True    True  False
# 3         False    C  Southampton   yes  False    True  False
# 8         False  NaN  Southampton   yes  False    True  False
# 9         False  NaN    Cherbourg   yes  False    True  False
# ..          ...  ...          ...   ...    ...     ...    ...
# 874       False  NaN    Cherbourg   yes  False    True  False
# 875       False  NaN    Cherbourg   yes   True    True  False
# 879       False    C    Cherbourg   yes  False    True  False
# 880       False  NaN  Southampton   yes  False    True  False
# 887       False    B  Southampton   yes   True    True  False
#
# [233 rows x 16 columns]
